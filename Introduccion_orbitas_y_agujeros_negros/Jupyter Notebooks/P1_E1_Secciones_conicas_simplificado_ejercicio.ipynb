# %%
import numpy as np
import matplotlib.pyplot as plt

# 1. Círculo: x^2 + y^2 = r^2
r = ####
theta = np.linspace(0, 2 * np.pi, 500)
x_c = r * np.cos(theta)
y_c = r * np.sin(theta)

plt.figure(figsize=(7, 6))
plt.plot(x_c, y_c, 'b', lw=2, label=f'Círculo: $x^2 + y^2 = {r}^2$')
plt.plot([0, r], [0, 0], 'r--', marker='o', label=f'Radio $r = {r}$')
plt.gca().set_aspect('equal')
plt.title('1. Hola hola hola')
plt.legend(loc='upper right')
plt.grid(True, linestyle=':', alpha=0.7)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# 2. Elipse: (x^2 / a^2) + (y^2 / b^2) = 1
a_e, b_e = ####, ####
theta = np.linspace(0, 2 * np.pi, 500)
x_e = ####
y_e = ####

plt.figure(figsize=(7, 6))
plt.plot(x_e, y_e, 'g', lw=2, label=rf'Elipse: $\frac{{x^2}}{{{a_e}^2}} + \frac{{y^2}}{{{b_e}^2}} = 1$')
plt.gca().set_aspect('equal')
plt.title('2. Elipse')
plt.legend(loc='upper right')
plt.grid(True, linestyle=':', alpha=0.7)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# 3. Hipérbola: (x^2 / a^2) - (y^2 / b^2) = 1
a_h, b_h = 2, 1.5
t = np.linspace(-2, 2, 100)
x_hr = ####
y_hr = ####
x_hl = ####
y_hl = ####



plt.figure(figsize=(7, 6))
plt.plot(x_hr, y_hr, 'k', lw=2, label=rf'Hipérbola: $\frac{{x^2}}{{{a_h}^2}} - \frac{{y^2}}{{{b_h}^2}} = 1$')
plt.plot(x_hl, y_hl, 'k', lw=2)
plt.xlim(-6, 6)
plt.ylim(-4, 4)
plt.gca().set_aspect('equal')
plt.title('3. Hipérbola')
plt.legend(loc='upper right', fontsize='small')
plt.grid(True, linestyle=':', alpha=0.7)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# 4. Parábola: x^2 = 4py -> y = x^2 / (4p)
p = 1.5
x_p = np.linspace(-8, 8, 100)
y_p = ####

plt.figure(figsize=(7, 6))
plt.plot(x_p, y_p, 'darkorange', lw=2, label=rf'Parábola: $x^2 = 4({p})y$')
plt.ylim(-3, 8)
plt.title('4. Parábola')
plt.legend(loc='upper right')
plt.grid(True, linestyle=':', alpha=0.7)
plt.show()
