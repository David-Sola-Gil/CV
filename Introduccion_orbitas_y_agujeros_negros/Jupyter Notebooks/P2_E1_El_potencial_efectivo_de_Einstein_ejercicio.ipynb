# %%
import numpy as np
import matplotlib.pyplot as plt
#import matplotlib as mpl
#mpl.rcParams['figure.dpi'] = 600

# Constantes para un plot bonito
m = 100.0    # Masa
k = 1.0      # Constante (G * M)
c = 1        # Velocidad de la luz
l = 4*k/c    # Momento angular

def potencial_efectivo_einstein(r):
    attractivo = ####
    repulsivo= ####
    einstein = ####
    return attractivo + repulsivo + einstein

def potencial_efectivo_newton(r):
    attractivo = ####
    repulsivo = ####
    return attractivo + repulsivo

# Define el rango de r (evita el radio de Schwarzschild)
r = ####
v_eff_einstein = potencial_efectivo_einstein(r)
v_eff_newton = potencial_efectivo_newton(r)

# Calcula máximo y mínimo de la órbita
r_max = ####
v_max = potencial_efectivo_einstein(r_max)
r_stable = ####
v_stable = potencial_efectivo_einstein(r_stable)

# Plotting
plt.figure(figsize=(10, 6))
plt.plot(r, v_eff_einstein, label=r'$V_{eff, GR}(r)$', color='black', lw=2)

# Add components to show how they combine
plt.plot(r, ####, '--', label='Atractivo ($\\propto -1/r$)', alpha=0.5, color='red')
plt.plot(r, ####, '--', label='Repulsivo ($\\propto 1/r^2$)', alpha=0.5,color='blue')
plt.plot(r,  ####, '--', label='Einstein ($\\propto -1/r^3$)', alpha=0.5,color='green')

#Add Newton's plot
plt.plot(r, v_eff_newton, label=r'$V_{eff, N}(r)$', color='purple', lw=2)

# Highlight the stable orbit point
plt.plot(r_stable, v_stable, 'ro')
plt.plot(r_max, v_max, 'ro')

# Formatting the plot
plt.axhline(0, color='black', linewidth=0.5)
plt.xlim(0, 100.0)
plt.ylim(v_stable - 5, 5)
plt.xlabel('r (m)')
plt.ylabel('Energía $(kg)$')
plt.title('Potencial efectivo con la gravedad de Einstein')
plt.legend()
plt.grid(True, linestyle=':', alpha=0.6)

plt.show()
