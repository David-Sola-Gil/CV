# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
#mpl.rcParams['figure.dpi'] = 600

# Constantes para un plot bonito
m = 1.0     # Masa
k = 10.0    # Constante k = G * M
l = 2.0     # Momento angular por unidad de masa

# Función para calcular el potencial
def potencial_efectivo(r):
    attractivo = ####
    repulsivo = ####
    return attractivo + repulsivo

# Acorta el rango de r para no dividir entre 0
r = np.linspace(####, ####, ####)
v_eff = potencial_efectivo(r)

# Calcula el mínimo para dibujar un punto
r_min = ####
v_min = potencial_efectivo(r_min)

# Gráficos
plt.figure(figsize=(10, 6))
plt.plot(r, v_eff, label=r'$V_{eff}(r)$', color='purple', lw=2)

# Añadimos los distintos términos para compararlos también
plt.plot(r,####, '--', label='Atractivo ($-10/r$)', alpha=0.5, color='red')
plt.plot(r,####, '--', label='Repulsivo ($2/r^2$)', alpha=0.5,color='blue')

# Punto de órbita estable
plt.plot(r_min, v_min, 'ro')

# Creando la gráfica final, añadiendo líneas horizontales para hablar de los tipos de órbitas
plt.axhline(####, color='orange', linewidth=1, label='E0')
plt.axhline(####, color='orange', linewidth=1, label='E1')
plt.axhline(####, color='orange', linewidth=1, label='E2')
plt.axhline(####, color='orange', linewidth=1, label='E3')
plt.ylim(v_min - 5, 20)
plt.xlim(0, 6)
plt.xlabel('r (m)')
plt.ylabel('Energía (J)')
plt.title('Potencial efectivo con la gravedad de Newton')
plt.legend()
plt.grid(True, linestyle=':', alpha=0.6)

plt.show()
