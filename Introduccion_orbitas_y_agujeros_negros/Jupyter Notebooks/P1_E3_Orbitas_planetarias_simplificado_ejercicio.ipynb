# %%
import numpy as np
import matplotlib.pyplot as plt

def get_radius(theta_list, e, r0):
    return r0 / (1 + e * np.cos(theta_list))

theta = np.linspace(0, 2 * np.pi, 500)

# 1. Círculo: e = 0
x_c = get_radius(theta, 0, 1) * ####
y_c = get_radius(theta, 0, 1) * ####

plt.figure(figsize=(6, 6))
plt.plot(x_c, y_c, 'b', lw=2)
plt.scatter([0], [0], color='yellow', s=100, edgecolors='orange', label='Sol')
plt.gca().set_aspect('equal')
plt.title('1. Círculo ($e=0$)')
plt.grid(True, linestyle=':', alpha=0.7)
plt.legend(loc='upper right')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

def get_radius(theta_list, e, r0):
    return r0 / (1 + e * np.cos(theta_list))

theta = np.linspace(0, 2 * np.pi, 500)

# 2. Elipse: e = 1/2
x_e = ####
y_e = ####

plt.figure(figsize=(6, 6))
plt.plot(x_e, y_e, 'g', lw=2)
plt.scatter([0], [0], color='yellow', s=100, edgecolors='orange', label='Sol')
plt.gca().set_aspect('equal')
plt.title('2. Elipse ($0 < e < 1$)')
plt.grid(True, linestyle=':', alpha=0.7)
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

def get_radius(theta_list, e, r0):
    return r0 / (1 + e * np.cos(theta_list))

# 3. Hipérbola: e = 2
e_hyp = 2

# Cuidado con la hipérbola, hay que poner un ángulo límite para graficarla.
limit_phi_hyp = ####


phi_hyp = np.linspace(-limit_phi_hyp + 0.01, limit_phi_hyp - 0.01, 1000)
x_h = ####
y_h = ####

plt.figure(figsize=(6, 6))
plt.plot(x_h, y_h, 'k', lw=2)
plt.scatter([0], [0], color='yellow', s=100, edgecolors='orange', label='Sol')
plt.xlim(-3, 3)
plt.ylim(-3, 3)
plt.gca().set_aspect('equal')
plt.title('3. Hipérbola ($e > 1$)')
plt.grid(True, linestyle=':', alpha=0.7)
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

def get_radius(theta_list, e, r0):
    return r0 / (1 + e * np.cos(theta_list))

# 4. Parábola: e = 1
# Aquí tenemos también un rango distinto de ángulos
limit_phi_par = np.arccos(####)
phi_par = np.linspace(####, ####, 1000)

x_p = get_radius(####, ####, ####) * np.cos(phi_par)
y_p = get_radius(####, ####, ####) * np.sin(phi_par)

plt.figure(figsize=(6, 6))
plt.plot(x_p, y_p, 'darkorange', lw=2)
plt.scatter([0], [0], color='yellow', s=100, edgecolors='orange', label='Sol')
plt.ylim(-3, 3)
plt.xlim(-2, 2)
plt.title('4. Parábola ($e = 1$)')
plt.grid(True, linestyle=':', alpha=0.7)
plt.legend()
plt.show()
